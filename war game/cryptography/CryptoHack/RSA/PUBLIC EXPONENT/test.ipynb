# %%
from gmpy2 import *
from Crypto.Util.number import long_to_bytes, inverse

n = ...
e = 3
c = ...

print(iroot(c, 3))
# Out:
# (mpz(19098191227879222145994116373513638931820562309376309724645750109891594714309873971995719116826761478017369812498005255723345725724125513472006288864469540935986784685031057529497843787380223821407166269720), False)

# %%
from gmpy2 import *
from Crypto.Util.number import GCD

e = 3

n1 = ...
c1 = ...

n2 = ...
c2 = ...
# Out:
# 1
# 1

# %%
from Crypto.Util.number import inverse, long_to_bytes

n = ...
e = 65537
c = ...

p = ...
q = ...

phi_n = (p-1)*(q-1)

d = inverse(e, phi_n)

flag = long_to_bytes(pow(c, d, n)).decode()

print(flag)
# Out:
# crypto{f3rm47_w45_4_g3n1u5}
